# %%
# !pip install requests

# %%
from pprint import pprint
import requests
response = requests.get("http://host.docker.internal:8083/")
pprint(response.json())  # Expect {"version": "...", "commit": "..."}
# Out:
# {'commit': '8f1346537b7bbf271a32d604161e972ff9b9f9a3',
#  'kafka_cluster_id': '2i-Tms02SN6VN60s2x_HGw',
#  'version': '7.5.2-ccs'}
